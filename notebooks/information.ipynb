# %% [markdown]
# # Takeaway
#
# ## This Cookbook:
#
# ### https://github.com/ProjectPythia/healpix-cookbook/tree/main
#
# ## Uxarray:
# ### https://github.com/UXARRAY/uxarray
# ### Mattermost channel: hk25-uxarray
#
# ## About Me
# ### Hongyu Chen
# ### Email: hyvchen@ucdavis.edu
# ### Mattermost: hongyu.chen
